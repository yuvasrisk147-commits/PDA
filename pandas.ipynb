# %%
# !pip install numpy
# !pip install pandas

# %%
import pandas as pd 
import numpy as np

s = pd.Series() 
print("Pandas Series: ", s) 
data = np.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd
   
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
  
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Hp\OneDrive\New folder\PDA\data.csv")
print(df.head())

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 188.0+ bytes
# None

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# 0    0
# dtype: int64

# %%
ages = df[df['age'] > 25]
print(ages)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ages = df[df['age'] > 25]
#       2 print(ages)
#
# File c:\Users\Hp\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Hp\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'age'

# %%
df['total'] = df['a'] + df['b']
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['total'] = df['a'] + df['b']
#       2 print(df.head())
#
# NameError: name 'df' is not defined

# %%
res = df.groupby('category')['sales'].sum()
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 res=df.groupby('category')['sales'].sum()
#       2 print(res)
#
# File c:\Users\Hp\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
import pandas as pd 
s = pd.Series([10, 20, 30, 40])

# %%
s = pd.Series([85, 90, 78], index=["A", "B", "C"])

# %%
s[0]        
# Access first element 
s["A"]     # Access by label
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19164\4108854481.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# 85

# %%
s.mean(), s.max(), s.min()
# Out:
# (84.33333333333333, 90, 78)

# %%
data = { 
"Name": ["Amit", "Riya", "Karan"], 
"Marks": [85, 90, 78] 
} 
df = pd.DataFrame(data)

# %%
df["Name"]
# Out:
# 0     Amit
# 1     Riya
# 2    Karan
# Name: Name, dtype: object

# %%
df.loc[0] 
df.iloc[1]
# Out:
# Name     Riya
# Marks      90
# Name: 1, dtype: object

# %%
df["Grade"] = ["A", "A+", "B"]

# %%
df.drop("Grade", axis=1)
# Out:
#     Name  Marks
# 0   Amit     85
# 1   Riya     90
# 2  Karan     78

# %%
df[df["Marks"] > 80]
# Out:
#    Name  Marks Grade
# 0  Amit     85     A
# 1  Riya     90    A+

# %%
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   84.333333
# std     6.027714
# min    78.000000
# 25%    81.500000
# 50%    85.000000
# 75%    87.500000
# max    90.000000
