# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    }
  }
}
# Out:
# {'nbformat': 4, 'nbformat_minor': 0, 'metadata': {'colab': {'provenance': []}}}

# %%
{
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
}
# Out:
# {'kernelspec': {'name': 'python3', 'display_name': 'Python 3'}}

# %%
{"language_info": {
      "name": "python"
    }
}
# Out:
# {'language_info': {'name': 'python'}}

# %%
{
"cells": 
    {
      "cell_type": "markdown",
      "source": [
        "#Funtion"
      ],
      "metadata": {
        "id": "SoRe_FCeNwDq"
      }
    }
}
# Out:
# {'cells': {'cell_type': 'markdown',
#   'source': ['#Funtion'],
#   'metadata': {'id': 'SoRe_FCeNwDq'}}}

# %%
{
      "cell_type": "code",
      "source": [
        "def fun():\n",
        "  print(\"Welcome\")\n",
        "fun()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
      }
}
# Out:
# {'cell_type': 'code',
#  'source': ['def fun():\n', '  print("Welcome")\n', 'fun()'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
 "id": "dK9tBOQ7Nyoc",
        "outputId": "5dda012f-b5c4-4479-e860-e32e858c2af1"
}
# Out:
# {'id': 'dK9tBOQ7Nyoc', 'outputId': '5dda012f-b5c4-4479-e860-e32e858c2af1'}

# %%
{
    "cell_type": "markdown",
    "source": [
        
        "#operators"
      ],
      "metadata": {
        "id": "Dzzu2YijODBd"
    }
}
# Out:
# {'cell_type': 'markdown',
#  'source': ['#operators'],
#  'metadata': {'id': 'Dzzu2YijODBd'}}

# %%
{
      "cell_type": "code",
      "source": [
        "#Arithmetic operators\n",
        "a=17\n",
        "b=5\n",
        "print(a+b)\n",
        "print(a-b)\n",
        "print(a*b)\n",
        "print(a/b)\n",
        "print(a//b)\n",
        "print(a%b)\n",
        "print(a**b)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        }
      }
 }
# Out:
# {'cell_type': 'code',
#  'source': ['#Arithmetic operators\n',
#   'a=17\n',
#   'b=5\n',
#   'print(a+b)\n',
#   'print(a-b)\n',
#   'print(a*b)\n',
#   'print(a/b)\n',
#   'print(a//b)\n',
#   'print(a%b)\n',
#   'print(a**b)\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
"id": "qQIDCDmhOes5",
        "outputId": "8d84cc5a-36ef-4f50-af75-6a97e88287a4"
},
# Out:
# ({'id': 'qQIDCDmhOes5', 'outputId': '8d84cc5a-36ef-4f50-af75-6a97e88287a4'},)

# %%
{
      "cell_type": "markdown",
      "source": [
        "#comparison operators\n"
      ],
      "metadata": {
        "id": "v63FqrgePghL"
      }
}
# Out:
# {'cell_type': 'markdown',
#  'source': ['#comparison operators\n'],
#  'metadata': {'id': 'v63FqrgePghL'}}

# %%
{
      "cell_type": "code",
      "source": [
        "a=7\n",
        "b=5\n",
        "print(a>b)\n",
        "print(a<b)\n",
        "print(a>=b)\n",
        "print(a!=b)\n",
        "print(a==b)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
    }
}
# Out:
# {'cell_type': 'code',
#  'source': ['a=7\n',
#   'b=5\n',
#   'print(a>b)\n',
#   'print(a<b)\n',
#   'print(a>=b)\n',
#   'print(a!=b)\n',
#   'print(a==b)\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
"id": "_xNVXDUCPn6Y",
        "outputId": "7db1002a-df58-479b-c52c-b47bd5d93db2"
}
# Out:
# {'id': '_xNVXDUCPn6Y', 'outputId': '7db1002a-df58-479b-c52c-b47bd5d93db2'}

# %%
{
        "execution_count": null,
      "outputs": [

        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "True\n",
            "False\n",
            "True\n",
            "True\n",
            "False\n"
          ]
        }
      ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 {
# ----> 2         "execution_count": null,
#       3       "outputs": [
#       4
#       5         {
#       6           "output_type": "stream",
#       7           "name": "stdout",
#       8           "text": [
#       9             "True\n",
#      10             "False\n",
#      11             "True\n",
#      12             "True\n",
#      13             "False\n"
#      14           ]
#      15         }
#      16       ]
#      17 }
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#logical Operators"
      ],
      "metadata": {
        "id": "BCtt-vBmQKM_"
    }
}
# Out:
# {'cell_type': 'markdown',
#  'source': ['#logical Operators'],
#  'metadata': {'id': 'BCtt-vBmQKM_'}}

# %%
{
      "cell_type": "code",
      "source": [
        "a=True\n",
        "b=False\n",
        "print(a and b)\n",
        "print(a or b)\n",
        "print( not b)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
    }
}
# Out:
# {'cell_type': 'code',
#  'source': ['a=True\n',
#   'b=False\n',
#   'print(a and b)\n',
#   'print(a or b)\n',
#   'print( not b)'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
"id": "ApYhvgJVQM3O",
        "outputId": "38fd87a2-907f-4988-c65b-dab3a0983a45"
}
# Out:
# {'id': 'ApYhvgJVQM3O', 'outputId': '38fd87a2-907f-4988-c65b-dab3a0983a45'}

# %%
{
     "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "False\n",
            "True\n",
            "True\n"
          ]
        }
    ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 {
# ----> 2      "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "False\n",
#       9             "True\n",
#      10             "True\n"
#      11           ]
#      12         }
#      13     ]
#      14 }
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#Bitwise operators\n"
      ],
      "metadata": {
        "id": "dXvYBr5XQ2q3"
    }
}
# Out:
# {'cell_type': 'markdown',
#  'source': ['#Bitwise operators\n'],
#  'metadata': {'id': 'dXvYBr5XQ2q3'}}

# %%
{
      "cell_type": "code",
      "source": [
        "a=5\n",
        "b=2\n",
        "print(a&b)\n",
        "print(a/b)\n",
        "print(~a)\n",
        "print(a^b)\n",
        "print(a>>2)\n",
        "print(a<<2)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
      }
    }
# Out:
# {'cell_type': 'code',
#  'source': ['a=5\n',
#   'b=2\n',
#   'print(a&b)\n',
#   'print(a/b)\n',
#   'print(~a)\n',
#   'print(a^b)\n',
#   'print(a>>2)\n',
#   'print(a<<2)\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{  
        "id": "_gKx5u0tQ48b",
        "outputId": "983190d2-8713-49b5-f194-13331483dbc1"
},
# Out:
# ({'id': '_gKx5u0tQ48b', 'outputId': '983190d2-8713-49b5-f194-13331483dbc1'},)

# %%
{
"execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "0\n",
            "2.5\n",
            "-6\n",
            "7\n",
            "1\n",
            "20\n"
          ]
        }
    ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 {
# ----> 2 "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "0\n",
#       9             "2.5\n",
#      10             "-6\n",
#      11             "7\n",
#      12             "1\n",
#      13             "20\n"
#      14           ]
#      15         }
#      16     ]
#      17 }
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#Assignment operators"
      ],
      "metadata": {
        "id": "QC9mny3rRTmc"
    }
},
# Out:
# ({'cell_type': 'markdown',
#   'source': ['#Assignment operators'],
#   'metadata': {'id': 'QC9mny3rRTmc'}},)

# %%
{
      "cell_type": "code",
      "source": [
        "a=10\n",
        "b=2\n",
        "print(a+b)\n",
        "print(a==b)\n",
        "print(a!=b)\n",
        "print(a>=b)\n",
        "print(b<=a)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
    }
}
# Out:
# {'cell_type': 'code',
#  'source': ['a=10\n',
#   'b=2\n',
#   'print(a+b)\n',
#   'print(a==b)\n',
#   'print(a!=b)\n',
#   'print(a>=b)\n',
#   'print(b<=a)'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
    "id": "bqQ9u2TCRaAF",
        "outputId": "2d5a9cbb-76e0-4cfc-d709-c5ce1a623f29"
}
# Out:
# {'id': 'bqQ9u2TCRaAF', 'outputId': '2d5a9cbb-76e0-4cfc-d709-c5ce1a623f29'}

# %%
{
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "12\n",
            "False\n",
            "True\n",
            "True\n",
            "True\n"
          ]
        }
    ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 {
# ----> 2       "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "12\n",
#       9             "False\n",
#      10             "True\n",
#      11             "True\n",
#      12             "True\n"
#      13           ]
#      14         }
#      15     ]
#      16 }
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#identify operators"
      ],
      "metadata": {
        "id": "ikuOEkXTSc8S"
      }
}
# Out:
# {'cell_type': 'markdown',
#  'source': ['#identify operators'],
#  'metadata': {'id': 'ikuOEkXTSc8S'}}

# %%
{
      "cell_type": "code",
      "source": [
        "a=10\n",
        "b=5\n",
        "c=a\n",
        "print( c is a)\n",
        "print(a is not b)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
    }
}
# Out:
# {'cell_type': 'code',
#  'source': ['a=10\n',
#   'b=5\n',
#   'c=a\n',
#   'print( c is a)\n',
#   'print(a is not b)\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{"id": "5__I3zWGSjXl",
        "outputId": "b6202b9f-7b03-441e-c360-a66e760ec4b8"
      },
# Out:
# ({'id': '5__I3zWGSjXl', 'outputId': 'b6202b9f-7b03-441e-c360-a66e760ec4b8'},)

# %%
{
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "True\n",
            "True\n"
          ]
        }
      ]
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 {
# ----> 2       "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "True\n",
#       9             "True\n"
#      10           ]
#      11         }
#      12       ]
#      13     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "code",
      "source": [
        "#ternary operators"
      ],
      "metadata": {
        "id": "QV6sJo15Sxne"
      },
}
# Out:
# {'cell_type': 'code',
#  'source': ['#ternary operators'],
#  'metadata': {'id': 'QV6sJo15Sxne'}}

# %%
{"execution_count": null,
      "outputs": []
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 {"execution_count": null,
#       2       "outputs": []
#       3     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "code",
      "source": [
        "min = a if a<b else b\n",
        "print(min)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        }
      }
 }
# Out:
# {'cell_type': 'code',
#  'source': ['min = a if a<b else b\n', 'print(min)\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{"id": "FYgBiOrcS2Kc",
        "outputId": "0067f89c-038a-4a9d-9077-67b030935f42"
      },
# Out:
# ({'id': 'FYgBiOrcS2Kc', 'outputId': '0067f89c-038a-4a9d-9077-67b030935f42'},)

# %%
{
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "5\n"
          ]
        }
      ]
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 {
# ----> 2       "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "5\n"
#       9           ]
#      10         }
#      11       ]
#      12     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#membership platform"
      ],
      "metadata": {
        "id": "5GFPON1QTXTA"
      }
    },
# Out:
# ({'cell_type': 'markdown',
#   'source': ['#membership platform'],
#   'metadata': {'id': '5GFPON1QTXTA'}},)

# %%
{
      "cell_type": "code",
      "source": [
        "x=24\n",
        "y=20\n",
        "list1 = [10,20,30,40,50]\n",
        "if x not in list1:\n",
        "  print(\"x not in list\")\n",
        "if y in list1:\n",
        "  print(\"y is in list\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
      }
    }
# Out:
# {'cell_type': 'code',
#  'source': ['x=24\n',
#   'y=20\n',
#   'list1 = [10,20,30,40,50]\n',
#   'if x not in list1:\n',
#   '  print("x not in list")\n',
#   'if y in list1:\n',
#   '  print("y is in list")'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{"id": "8sZbe_B-TbYM",
        "outputId": "340556e3-69bb-4eec-8381-4c827f2bd284"
      },
# Out:
# ({'id': '8sZbe_B-TbYM', 'outputId': '340556e3-69bb-4eec-8381-4c827f2bd284'},)

# %%
{
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "x not in list\n",
            "y is in list\n"
          ]
        }
      ]
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 {
# ----> 2       "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "x not in list\n",
#       9             "y is in list\n"
#      10           ]
#      11         }
#      12       ]
#      13     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#question output"
      ],
      "metadata": {
        "id": "M_dUACltVyTD"
      }
    },
# Out:
# ({'cell_type': 'markdown',
#   'source': ['#question output'],
#   'metadata': {'id': 'M_dUACltVyTD'}},)

# %%
{
      "cell_type": "code",
      "source": [
        "print(100/10*10)\n",
        "print(5-2+3)\n",
        "print(5-(2+3))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
      }
}
# Out:
# {'cell_type': 'code',
#  'source': ['print(100/10*10)\n', 'print(5-2+3)\n', 'print(5-(2+3))'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
        "id": "hsaaH0nSV4Ns",
        "outputId": "b55ba04f-4004-4828-dd92-a856e846f49c"
      },
# Out:
# ({'id': 'hsaaH0nSV4Ns', 'outputId': 'b55ba04f-4004-4828-dd92-a856e846f49c'},)

# %%
{
        "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "100.0\n",
            "6\n",
            "0\n"
          ]
        }
      ]
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 {
# ----> 2         "execution_count": null,
#       3       "outputs": [
#       4         {
#       5           "output_type": "stream",
#       6           "name": "stdout",
#       7           "text": [
#       8             "100.0\n",
#       9             "6\n",
#      10             "0\n"
#      11           ]
#      12         }
#      13       ]
#      14     }
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#unit 1 code"
      ],
      "metadata": {
        "id": "4uhFeRx0W-gL"
      }
    },
# Out:
# ({'cell_type': 'markdown',
#   'source': ['#unit 1 code'],
#   'metadata': {'id': '4uhFeRx0W-gL'}},)

# %%
{
      "cell_type": "code",
      "source": [
        "#introduction python programming"
      ],
      "metadata": {
        "id": "WlXuZegwXdP8"
      },
}
# Out:
# {'cell_type': 'code',
#  'source': ['#introduction python programming'],
#  'metadata': {'id': 'WlXuZegwXdP8'}}

# %%
{"execution_count": null,
      "outputs": []
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 {"execution_count": null,
#       2       "outputs": []
#       3     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "code",
      "source": [
        "#print hello world\n",
        "print(\"hello world\")\n",
        "print(\"welcome to PDA\")\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
      }
}
# Out:
# {'cell_type': 'code',
#  'source': ['#print hello world\n',
#   'print("hello world")\n',
#   'print("welcome to PDA")\n'],
#  'metadata': {'colab': {'base_uri': 'https://localhost:8080/'}}}

# %%
{
        "id": "PCAAfJ2vYR15",
        "outputId": "76da390e-22af-4d69-e294-a35777fbeb49"
      },
# Out:
# ({'id': 'PCAAfJ2vYR15', 'outputId': '76da390e-22af-4d69-e294-a35777fbeb49'},)

# %%
{
 
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "hello world\n",
            "welcome to PDA\n"
          ]
        }
      ]
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 {
#       2
# ----> 3       "execution_count": null,
#       4       "outputs": [
#       5         {
#       6           "output_type": "stream",
#       7           "name": "stdout",
#       8           "text": [
#       9             "hello world\n",
#      10             "welcome to PDA\n"
#      11           ]
#      12         }
#      13       ]
#      14     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "code",
      "source": [
        "#introduction\n",
        "print(\"i have no indentation\")\n",
        "print(\"i have indentation\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "EYR3-b7LYkkr",
        "outputId": "29d5e440-f70a-428e-b2c2-7af095377692"
      },
      "execution_count": 40,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "i have no indentation\n",
            "i have indentation\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#introduction\n',
#    'print("i have no indentation")\n',
#    'print("i have indentation")'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'EYR3-b7LYkkr',
#    'outputId': '29d5e440-f70a-428e-b2c2-7af095377692'},
#   'execution_count': 40,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ['i have no indentation\n', 'i have indentation\n']}]},)

# %%
{
      "cell_type": "markdown",
      "source": [
        "#Assignment passing"
      ],
      "metadata": {
        "id": "4ycgpVliOopb"
      }
    },
{
      "cell_type": "code",
      "source": [
        "def evenodd(x):\n",
        "  if x%2==0:\n",
        "    print(\"Even\")"
      ],
      "metadata": {
        "id": "wO4qB1oPOx47"
      },
      "execution_count": null,
      "outputs": []
    },
{
      "cell_type": "markdown",
      "source": [
        "#keyword argument"
      ],
      "metadata": {
        "id": "mD5d202HPFqG"
      }
    },
{
      "cell_type": "code",
      "source": [
        "def person(name,age):\n",
        "  print(\"Hi i am\",name)\n",
        "  print(\"Hi i am\",age)\n",
        "print(\"case 1\")\n",
        "person(\"Ram\",12)\n",
        "print(\"case 2\")\n",
        "person(25,\"Ram\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "HpSzEcIDPGFA",
        "outputId": "42b74b58-5d2a-4655-8ea4-48a244d2b7cf"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "case 1\n",
            "Hi i am Ram\n",
            "Hi i am 12\n",
            "case 2\n",
            "Hi i am 25\n",
            "Hi i am Ram\n"
          ]
        }
      ]
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 20
#       1 {
#       2       "cell_type": "markdown",
#       3       "source": [
#    (...)
#       8       }
#       9     },
#      10 {
#      11       "cell_type": "code",
#      12       "source": [
#      13         "def evenodd(x):\n",
#      14         "  if x%2==0:\n",
#      15         "    print(\"Even\")"
#      16       ],
#      17       "metadata": {
#      18         "id": "wO4qB1oPOx47"
#      19       },
# ---> 20       "execution_count": null,
#      21       "outputs": []
#      22     },
#      23 {
#      24       "cell_type": "markdown",
#      25       "source": [
#    (...)
#      30       }
#      31     },
#      32 {
#      33       "cell_type": "code",
#      34       "source": [
#    (...)
#      64       ]
#      65     },
#
# NameError: name 'null' is not defined

# %%
{
      "cell_type": "markdown",
      "source": [
        "#Funtion within funtion"
      ],
      "metadata": {
        "id": "tZnLQoiOQC_8"
      }
    },
{
      "cell_type": "code",
      "source": [
        "def f1():\n",
        "    s=\"I love india\"\n",
        "    def f2():\n",
        "       print(s)\n",
        "    f2()\n",
        "f1()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "HDmHb8reQFA9",
        "outputId": "0aeea908-7c3f-4e80-9ccf-3d1054abd37a"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "I love india\n"
          ]
        }
      ]
    },
{
      "cell_type": "markdown",
      "source": [
        "#getting type of variable"
      ],
      "metadata": {
        "id": "atN5QXa2e8Q4"
      }
    },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 27
#       1 {
#       2       "cell_type": "markdown",
#       3       "source": [
#    (...)
#       8       }
#       9     },
#      10 {
#      11       "cell_type": "code",
#      12       "source": [
#      13         "def f1():\n",
#      14         "    s=\"I love india\"\n",
#      15         "    def f2():\n",
#      16         "       print(s)\n",
#      17         "    f2()\n",
#      18         "f1()"
#      19       ],
#      20       "metadata": {
#      21         "colab": {
#      22           "base_uri": "https://localhost:8080/"
#      23         },
#      24         "id": "HDmHb8reQFA9",
#      25         "outputId": "0aeea908-7c3f-4e80-9ccf-3d1054abd37a"
#      26       },
# ---> 27       "execution_count": null,
#      28       "outputs": [
#      29         {
# ...

# %%
{
      "cell_type": "code",
      "source": [
        "n1 = 55\n",
        "n2 = 55.6\n",
        "n3 = \"hello\"\n",
        "n4 = [1,2,3]\n",
        "n5 = {\"a\":1,\"b\":2,\"c\":3}\n",
        "n6 = True\n",
        "print(type(n1))\n",
        "print(type(n2))\n",
        "print(type(n3))\n",
        "print(type(n4))\n",
        "print(type(n5))\n",
        "print(type(bool))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "v8gKNyBxfDnt",
        "outputId": "9c48b8be-5bd9-4ba9-b256-04b3e489ee43"
      },
      "execution_count": 18,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'int'>\n",
            "<class 'float'>\n",
            "<class 'str'>\n",
            "<class 'list'>\n",
            "<class 'dict'>\n",
            "<class 'type'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['n1 = 55\n',
#    'n2 = 55.6\n',
#    'n3 = "hello"\n',
#    'n4 = [1,2,3]\n',
#    'n5 = {"a":1,"b":2,"c":3}\n',
#    'n6 = True\n',
#    'print(type(n1))\n',
#    'print(type(n2))\n',
#    'print(type(n3))\n',
#    'print(type(n4))\n',
#    'print(type(n5))\n',
#    'print(type(bool))'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'v8gKNyBxfDnt',
#    'outputId': '9c48b8be-5bd9-4ba9-b256-04b3e489ee43'},
#   'execution_count': 18,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'int'>\n",
#      "<class 'float'>\n",
#      "<class 'str'>\n",
#      "<class 'list'>\n",
#      "<class 'dict'>\n",
#      "<class 'type'>\n"]}]},)

# %%
{
      "cell_type": "markdown",
      "source": [
        "#python data types"
      ],
      "metadata": {
        "id": "0AF_jS7chJ0u"
      }
    },
{
      "cell_type": "code",
      "source": [
        "#numeric data type\n",
        "a = 5\n",
        "print(type(a))\n",
        "b = 5.2\n",
        "print(type(b))\n",
        "c = 5+2j\n",
        "print(type(c))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "7aGtXovKhN5X",
        "outputId": "94c026a8-9bd2-4c3d-8525-cf76d5ad9a5a"
      },
      "execution_count": 25,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'int'>\n",
            "<class 'float'>\n",
            "<class 'complex'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#numeric data type\n',
#    'a = 5\n',
#    'print(type(a))\n',
#    'b = 5.2\n',
#    'print(type(b))\n',
#    'c = 5+2j\n',
#    'print(type(c))'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': '7aGtXovKhN5X',
#    'outputId': '94c026a8-9bd2-4c3d-8525-cf76d5ad9a5a'},
#   'execution_count': 25,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'int'>\n",
#      "<class 'float'>\n",
#      "<class 'complex'>\n"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#python variables\n",
        "x=55.7\n",
        "s=\"Hello\"\n",
        "print(x)\n",
        "print(s)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "epBfKlWwksxd",
        "outputId": "c66503e0-68ab-440c-805f-66803a989588"
      },
      "execution_count": 27,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "55.7\n",
            "Hello\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#python variables\n',
#    'x=55.7\n',
#    's="Hello"\n',
#    'print(x)\n',
#    'print(s)'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'epBfKlWwksxd',
#    'outputId': 'c66503e0-68ab-440c-805f-66803a989588'},
#   'execution_count': 27,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ['55.7\n', 'Hello\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#type casting a variables\n",
        "i=int(x)\n",
        "s1=str(x)\n",
        "print(i)\n",
        "print(s1)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "hUsIhtrKkxcu",
        "outputId": "88a2e2fd-2fed-4ccc-b47f-044f10067483"
      },
      "execution_count": 28,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "55\n",
            "55.7\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#type casting a variables\n',
#    'i=int(x)\n',
#    's1=str(x)\n',
#    'print(i)\n',
#    'print(s1)'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'hUsIhtrKkxcu',
#    'outputId': '88a2e2fd-2fed-4ccc-b47f-044f10067483'},
#   'execution_count': 28,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ['55\n', '55.7\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#python data types\n",
        "# numeric data types\n",
        "a=5\n",
        "print(type(a))\n",
        "b=5.2\n",
        "print(type(b))\n",
        "c= 5 + 2j\n",
        "print(type(c))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "DdLixQGJk19x",
        "outputId": "d97e082b-14b7-4857-eeba-38267b71b542"
      },
      "execution_count": 30,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'int'>\n",
            "<class 'float'>\n",
            "<class 'complex'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#python data types\n',
#    '# numeric data types\n',
#    'a=5\n',
#    'print(type(a))\n',
#    'b=5.2\n',
#    'print(type(b))\n',
#    'c= 5 + 2j\n',
#    'print(type(c))'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'DdLixQGJk19x',
#    'outputId': 'd97e082b-14b7-4857-eeba-38267b71b542'},
#   'execution_count': 30,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'int'>\n",
#      "<class 'float'>\n",
#      "<class 'complex'>\n"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#python data types\n",
        "# numeric data types\n",
        "a=5\n",
        "print(type(a))\n",
        "b=5.2\n",
        "print(type(b))\n",
        "c= 5 + 2j\n",
        "print(type(c))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "qG2_O0NNlBkO",
        "outputId": "249a7f4b-6150-4387-82d8-52fd323a0fb9"
      },
      "execution_count": 32,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'int'>\n",
            "<class 'float'>\n",
            "<class 'complex'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#python data types\n',
#    '# numeric data types\n',
#    'a=5\n',
#    'print(type(a))\n',
#    'b=5.2\n',
#    'print(type(b))\n',
#    'c= 5 + 2j\n',
#    'print(type(c))'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'qG2_O0NNlBkO',
#    'outputId': '249a7f4b-6150-4387-82d8-52fd323a0fb9'},
#   'execution_count': 32,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'int'>\n",
#      "<class 'float'>\n",
#      "<class 'complex'>\n"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#list\n",
        "a=[]\n",
        "print(type(a))\n",
        "b=[1,2,3]\n",
        "print(b)\n",
        "c=[1,2.3,\"A\",\"Mango\"]\n",
        "print(c)\n",
        "print(b[0])\n",
        "print(b[1])\n",
        "print(c[-1])\n",
        "print(c[-2])\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "20yAai0tlG1f",
        "outputId": "aaa086b4-a4a7-4fac-d7e0-7956d3dba3bb"
      },
      "execution_count": 33,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'list'>\n",
            "[1, 2, 3]\n",
            "[1, 2.3, 'A', 'Mango']\n",
            "1\n",
            "2\n",
            "Mango\n",
            "A\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#list\n',
#    'a=[]\n',
#    'print(type(a))\n',
#    'b=[1,2,3]\n',
#    'print(b)\n',
#    'c=[1,2.3,"A","Mango"]\n',
#    'print(c)\n',
#    'print(b[0])\n',
#    'print(b[1])\n',
#    'print(c[-1])\n',
#    'print(c[-2])\n'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': '20yAai0tlG1f',
#    'outputId': 'aaa086b4-a4a7-4fac-d7e0-7956d3dba3bb'},
#   'execution_count': 33,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'list'>\n",
#      '[1, 2, 3]\n',
#      "[1, 2.3, 'A', 'Mango']\n",
#      '1\n',
#      '2\n',
#      'Mango\n',
#      'A\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#sequence data types\n",
        "s=\"Welcome to PDA\"\n",
        "print(type(s))\n",
        "print(s)\n",
        "print(s[1])\n",
        "print(s[-1])"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "9v8IHnT6lNL1",
        "outputId": "cace6ec6-dd22-4780-e419-8d070ed79615"
      },
      "execution_count": 34,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'str'>\n",
            "Welcome to PDA\n",
            "e\n",
            "A\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#sequence data types\n',
#    's="Welcome to PDA"\n',
#    'print(type(s))\n',
#    'print(s)\n',
#    'print(s[1])\n',
#    'print(s[-1])'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': '9v8IHnT6lNL1',
#    'outputId': 'cace6ec6-dd22-4780-e419-8d070ed79615'},
#   'execution_count': 34,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'str'>\n", 'Welcome to PDA\n', 'e\n', 'A\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#boo;ean\n",
        "print(type(False))\n",
        "print(type(True))\n",
        "if 1:\n",
        "    print(\"1 is true\")\n",
        "else:\n",
        "    print(\"0 is false\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "fRY-BZDglRb7",
        "outputId": "63da9187-906c-450c-a417-03c1f8cfe288"
      },
      "execution_count": 35,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'bool'>\n",
            "<class 'bool'>\n",
            "1 is true\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#boo;ean\n',
#    'print(type(False))\n',
#    'print(type(True))\n',
#    'if 1:\n',
#    '    print("1 is true")\n',
#    'else:\n',
#    '    print("0 is false")'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'fRY-BZDglRb7',
#    'outputId': '63da9187-906c-450c-a417-03c1f8cfe288'},
#   'execution_count': 35,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'bool'>\n", "<class 'bool'>\n", '1 is true\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#sets\n",
        "s1=()\n",
        "s2=(\"Beautiful day\")\n",
        "s3=set[\"A\",\"B\",\"C\"]\n",
        "print(type(s1))\n",
        "print(s2)\n",
        "for s in s3:\n",
        "    print(s,end=\"\")"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "G5tuslV1lVCW",
        "outputId": "78734a1e-453f-4d1e-9622-a45f57e56508"
      },
      "execution_count": 36,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'tuple'>\n",
            "Beautiful day\n",
            "*set['A', 'B', 'C']"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#sets\n',
#    's1=()\n',
#    's2=("Beautiful day")\n',
#    's3=set["A","B","C"]\n',
#    'print(type(s1))\n',
#    'print(s2)\n',
#    'for s in s3:\n',
#    '    print(s,end="")'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'G5tuslV1lVCW',
#    'outputId': '78734a1e-453f-4d1e-9622-a45f57e56508'},
#   'execution_count': 36,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'tuple'>\n",
#      'Beautiful day\n',
#      "*set['A', 'B', 'C']"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#dictionary\n",
        "d1={}\n",
        "d2={\"a\":1,\"b\":2,\"c\":3}\n",
        "d3={1:\"a\",2:\"b\",3:\"c\"}\n",
        "print(d2)\n",
        "print(d3[1])"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "YQRm_exulYIS",
        "outputId": "e8a8f3fd-e462-4ff3-e760-e1986a9d7e17"
      },
      "execution_count": 37,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "{'a': 1, 'b': 2, 'c': 3}\n",
            "a\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#dictionary\n',
#    'd1={}\n',
#    'd2={"a":1,"b":2,"c":3}\n',
#    'd3={1:"a",2:"b",3:"c"}\n',
#    'print(d2)\n',
#    'print(d3[1])'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'YQRm_exulYIS',
#    'outputId': 'e8a8f3fd-e462-4ff3-e760-e1986a9d7e17'},
#   'execution_count': 37,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["{'a': 1, 'b': 2, 'c': 3}\n", 'a\n']}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "# type conversion\n",
        "# implicit type conversion\n",
        "x=10\n",
        "y=10.8\n",
        "z=x+y\n",
        "print(type(x))\n",
        "print(type(y))\n",
        "print(type(z))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "UY6-4RVjlbJN",
        "outputId": "56758655-8c09-4b7e-c2f4-7d87e14cb07f"
      },
      "execution_count": 38,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'int'>\n",
            "<class 'float'>\n",
            "<class 'float'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['# type conversion\n',
#    '# implicit type conversion\n',
#    'x=10\n',
#    'y=10.8\n',
#    'z=x+y\n',
#    'print(type(x))\n',
#    'print(type(y))\n',
#    'print(type(z))'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'UY6-4RVjlbJN',
#    'outputId': '56758655-8c09-4b7e-c2f4-7d87e14cb07f'},
#   'execution_count': 38,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'int'>\n", "<class 'float'>\n", "<class 'float'>\n"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "#explicit\n",
        "s=\"Hello World\"\n",
        "t=type(s)\n",
        "u=list(s)\n",
        "v=set(s)\n",
        "print(type(s))\n",
        "print(type(t))\n",
        "print(type(u))\n",
        "print(type(v))\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "B9gibpL2leBn",
        "outputId": "2f5eb594-25ff-4bc8-fee8-011f3c0860d1"
      },
      "execution_count": 39,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'str'>\n",
            "<class 'type'>\n",
            "<class 'list'>\n",
            "<class 'set'>\n"
          ]
        }
      ]
    },
# Out:
# ({'cell_type': 'code',
#   'source': ['#explicit\n',
#    's="Hello World"\n',
#    't=type(s)\n',
#    'u=list(s)\n',
#    'v=set(s)\n',
#    'print(type(s))\n',
#    'print(type(t))\n',
#    'print(type(u))\n',
#    'print(type(v))\n'],
#   'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#    'id': 'B9gibpL2leBn',
#    'outputId': '2f5eb594-25ff-4bc8-fee8-011f3c0860d1'},
#   'execution_count': 39,
#   'outputs': [{'output_type': 'stream',
#     'name': 'stdout',
#     'text': ["<class 'str'>\n",
#      "<class 'type'>\n",
#      "<class 'list'>\n",
#      "<class 'set'>\n"]}]},)

# %%
{
      "cell_type": "code",
      "source": [
        "# explicit type conversion\n",
        "a=\"52.6\"\n",
        "b=(a)\n",
        "c=float(b)\n",
        "print(type(a))\n",
        "print(type(b))\n",
        "print(type(c))\n"
      ],
      "metadata": {
        "id": "SMTMlO6IljE0"
      },
}
# Out:
# {'cell_type': 'code',
#  'source': ['# explicit type conversion\n',
#   'a="52.6"\n',
#   'b=(a)\n',
#   'c=float(b)\n',
#   'print(type(a))\n',
#   'print(type(b))\n',
#   'print(type(c))\n'],
#  'metadata': {'id': 'SMTMlO6IljE0'}}
